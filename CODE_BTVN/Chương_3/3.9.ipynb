# %%
import numpy as np

# mô phỏng: Goals of 8 teams
goals = np.array([4, 2, 6, 1, 5, 3, 2, 4])

print("Tổng số bàn thắng:", goals.sum())
print("Số bàn trung bình:", goals.mean())
print("Số bàn lớn nhất:", goals.max())
print("Số bàn nhỏ nhất:", goals.min())
