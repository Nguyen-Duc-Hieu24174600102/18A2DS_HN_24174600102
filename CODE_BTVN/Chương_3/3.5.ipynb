# %%
import numpy as np

height = [72, 70, 68, 75, 78]
weight = [180, 190, 165, 210, 220]

arr_height = np.array(height)
arr_weight = np.array(weight)

print("Height:", arr_height)
print("Weight:", arr_weight)
