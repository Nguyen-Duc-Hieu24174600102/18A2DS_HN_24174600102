# %%
import numpy as np 
arr1 = np.arange(3) 
arr2=np.arange(3)[:,np.newaxis] 
#np.newaxis sử dụng để cho biết một chiều mới được thêm vào 
print(arr1) 
print(arr2)
# Out:
# [0 1 2]
# [[0]
#  [1]
#  [2]]
