# %%
import pandas as pd

# =========================
# 1. ĐỌC DỮ LIỆU
# =========================
hotel = pd.read_csv("hotel_info.csv")
booking = pd.read_csv("booking_records.csv")
review = pd.read_csv("guest_review.csv")


# =========================
# 2. LÀM SẠCH HOTEL_INFO
# =========================

# hotel_id
hotel["hotel_id"] = hotel["hotel_id"].astype(str).str.strip().str.upper()

# hotel_name
hotel["hotel_name"] = hotel["hotel_name"].astype(str).str.strip().str.title()

# city
hotel["city"] = hotel["city"].astype(str).str.strip().str.title()

# room_type
hotel["room_type"] = hotel["room_type"].astype(str).str.strip().str.title()

# base_price
hotel["base_price"] = (
    hotel["base_price"]
    .astype(str)
    .str.replace(r"[^\d.]", "", regex=True)
)

hotel["base_price"] = pd.to_numeric(hotel["base_price"], errors="coerce")
hotel["base_price"] = hotel["base_price"].fillna(hotel["base_price"].mean())


# =========================
# 3. LÀM SẠCH BOOKING_RECORDS
# =========================

# hotel_id
booking["hotel_id"] = booking["hotel_id"].astype(str).str.strip().str.upper()

# checkin_date
booking["checkin_date"] = pd.to_datetime(
    booking["checkin_date"], errors="coerce"
)

# nights
booking["nights"] = pd.to_numeric(booking["nights"], errors="coerce")
booking.loc[booking["nights"] <= 0, "nights"] = None
booking["nights"] = booking["nights"].fillna(1).astype(int)

# num_guests
booking["num_guests"] = pd.to_numeric(
    booking["num_guests"].astype(str).str.strip(),
    errors="coerce"
)
booking["num_guests"] = booking["num_guests"].fillna(1).astype(int)


# =========================
# 4. LÀM SẠCH GUEST_REVIEW
# =========================

# rating
review["rating"] = pd.to_numeric(review["rating"], errors="coerce")
review.loc[(review["rating"] < 1) | (review["rating"] > 5), "rating"] = None
review["rating"] = review["rating"].fillna(review["rating"].mean())

# comment
review["comment"] = review["comment"].fillna("").astype(str).str.strip()


# =========================
# 5. XUẤT FILE SẠCH
# =========================
hotel.to_csv("hotel_info_clean.csv", index=False)
booking.to_csv("booking_records_clean.csv", index=False)
review.to_csv("guest_review_clean.csv", index=False)

print("✅ Đã làm sạch và xuất 3 file CSV thành công!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       3 # =========================
#       4 # 1. ĐỌC DỮ LIỆU
#       5 # =========================
#       6 hotel = pd.read_csv("hotel_info.csv")
#
# File c:\Users\Hieu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\__init__.py:62
#      59 # let init-time option registration happen
#      60 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 62 from pandas.core.api import (
#      63     # dtype
#      64     ArrowDtype,
#      65     Int8Dtype,
#      66     Int16Dtype,
#      67     Int32Dtype,
#      68     Int64Dtype,
#      69     UInt8Dtype,
#      70     UInt16Dtype,
#      71     UInt32Dtype,
#      72     UInt64Dtype,
#      73     Float32Dtype,
#      74     Float64Dtype,
#      75     CategoricalDtype,
#      76     PeriodDtype,
#      77     IntervalDtype,
#      78     DatetimeTZDtype,
#      79     StringDtype,
#      80     BooleanDtype,
#      81     # missing
#      82     NA,
#      83     isna,
#      84     isnull,
#      85     notna,
#      86     notnull,
#      87     # indexes
#      88     Index,
#      89     CategoricalIndex,
#      90     RangeIndex,
#      91     MultiIndex,
#      92     IntervalIndex,
#      93     TimedeltaIndex,
#      94     DatetimeIndex,
#      95     PeriodIndex,
#      96     IndexSlice,
#      97     # tseries
#      98     NaT,
#      99     Period,
#     100     period_range,
#     101     Timedelta,
#     102     timedelta_range,
#     103     Timestamp,
#     104     date_range,
#     105     bdate_range,
#     106     Interval,
#     107     interval_range,
#     108     DateOffset,
#     109     # conversion
#     110     to_numeric,
#     111     to_datetime,
#     112     to_timedelta,
#     113     # misc
#     114     Flags,
#     115     Grouper,
#     116     factorize,
#     117     unique,
#     118     value_counts,
#     119     NamedAgg,
#     120     array,
#     121     Categorical,
#     122     set_eng_float_format,
#     123     Series,
#     124     DataFrame,
#     125 )
#     127 from pandas.core.dtypes.dtypes import SparseDtype
#     129 from pandas.tseries.api import infer_freq
#
# File c:\Users\Hieu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)     14     PeriodDtype,
#      15 )
#
# File c:\Users\Hieu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)     26     iNaT,
#      27 )
#
# File pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# File pandas/_libs/hashtable.pyx:1, in init pandas._libs.hashtable()
#
# File pandas/_libs/missing.pyx:40, in init pandas._libs.missing()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
